# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.layers import Flatten, Dense
from keras.models import Model
from tensorflow.keras.utils  import load_img, img_to_array
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.mobilenet import MobileNet, preprocess_input 
from keras.losses import categorical_crossentropy

# %%
# Working with pre trained model 

base_model = MobileNet( input_shape=(224,224,3), include_top= False )

for layer in base_model.layers:
  layer.trainable = False


x = Flatten()(base_model.output)
x = Dense(units=7 , activation='softmax' )(x)

# creating our model.
model = Model(base_model.input, x)

# %%
model.compile(optimizer='adam', loss= categorical_crossentropy , metrics=['accuracy']  )

# %%
train_datagen = ImageDataGenerator(
     zoom_range = 0.2, 
     shear_range = 0.2, 
     horizontal_flip=True, 
     rescale = 1./255
)

train_data = train_datagen.flow_from_directory(directory= "./dataset/train", 
                                               target_size=(224,224), 
                                               batch_size=32,
                                  )


train_data.class_indices
# Out:
# Found 28709 images belonging to 7 classes.
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
val_datagen = ImageDataGenerator(rescale = 1./255 )

val_data = val_datagen.flow_from_directory(directory= "./dataset/test", 
                                           target_size=(224,224), 
                                           batch_size=32,
                                  )
# Out:
# Found 7178 images belonging to 7 classes.

# %%
# to visualize the images in the traing data denerator 

t_img , label = train_data.next()

#-----------------------------------------------------------------------------
# function when called will prot the images 
def plotImages(img_arr, label):
  """
  input  :- images array 
  output :- plots the images 
  """
  count = 0
  for im, l in zip(img_arr,label) :
    plt.imshow(im)
    plt.title(im.shape)
    plt.axis = False
    plt.show()
    
    count += 1
    if count == 10:
      break

#-----------------------------------------------------------------------------
# function call to plot the images 
plotImages(t_img, label)

# %%
## having early stopping and model check point 

from keras.callbacks import ModelCheckpoint, EarlyStopping

# early stopping
es = EarlyStopping(monitor='val_accuracy', min_delta= 0.01 , patience= 5, verbose= 1, mode='auto')

# model check point
mc = ModelCheckpoint(filepath="best_model.h5", monitor= 'val_accuracy', verbose= 1, save_best_only= True, mode = 'auto')

# puting call back in a list 
call_back = [es, mc]

# %%
hist = model.fit_generator(train_data, 
                           steps_per_epoch= 24, 
                           epochs= 30, 
                           validation_data= val_data, 
                           validation_steps= 8, 
                           callbacks=[es,mc])
# Out:
# C:\Users\mimel\AppData\Local\Temp\ipykernel_19152\3175683993.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model.fit_generator(train_data,
# Epoch 1/30
# 24/24 [==============================] - ETA: 0s - loss: 14.0603 - accuracy: 0.2552
# Epoch 1: val_accuracy improved from -inf to 0.36719, saving model to best_model.h5
# 24/24 [==============================] - 83s 3s/step - loss: 14.0603 - accuracy: 0.2552 - val_loss: 7.2552 - val_accuracy: 0.3672
# Epoch 2/30
# 24/24 [==============================] - ETA: 0s - loss: 6.7279 - accuracy: 0.3438
# Epoch 2: val_accuracy did not improve from 0.36719
# 24/24 [==============================] - 78s 3s/step - loss: 6.7279 - accuracy: 0.3438 - val_loss: 5.7616 - val_accuracy: 0.3555
# Epoch 3/30
# 24/24 [==============================] - ETA: 0s - loss: 5.0921 - accuracy: 0.4219
# Epoch 3: val_accuracy improved from 0.36719 to 0.41406, saving model to best_model.h5
# 24/24 [==============================] - 59s 2s/step - loss: 5.0921 - accuracy: 0.4219 - val_loss: 6.2445 - val_accuracy: 0.4141
# Epoch 4/30
# 24/24 [==============================] - ETA: 0s - loss: 5.6648 - accuracy: 0.4219
# Epoch 4: val_accuracy did not improve from 0.41406
# 24/24 [==============================] - 67s 3s/step - loss: 5.6648 - accuracy: 0.4219 - val_loss: 4.7808 - val_accuracy: 0.3984
# Epoch 5/30
# 24/24 [==============================] - ETA: 0s - loss: 5.1942 - accuracy: 0.3971
# Epoch 5: val_accuracy improved from 0.41406 to 0.42969, saving model to best_model.h5
# 24/24 [==============================] - 55s 2s/step - loss: 5.1942 - accuracy: 0.3971 - val_loss: 4.5436 - val_accuracy: 0.4297
# Epoch 6/30
# 24/24 [==============================] - ETA: 0s - loss: 5.9983 - accuracy: 0.3906
# Epoch 6: val_accuracy did not improve from 0.42969
# 24/24 [==============================] - 58s 2s/step - loss: 5.9983 - accuracy: 0.3906 - val_loss: 7.5372 - val_accuracy: 0.3281
# Epoch 7/30
# 24/24 [==============================] - ETA: 0s - loss: 5.6714 - accuracy: 0.4596
# Epoch 7: val_accuracy improved from 0.42969 to 0.43750, saving model to best_model.h5
# 24/24 [==============================] - 80s 3s/step - loss: 5.6714 - accuracy: 0.4596 - val_loss: 6.0107 - val_accuracy: 0.4375
# Epoch 8/30
# 24/24 [==============================] - ETA: 0s - loss: 5.9611 - accuracy: 0.4557
# Epoch 8: val_accuracy did not improve from 0.43750
# 24/24 [==============================] - 50s 2s/step - loss: 5.9611 - accuracy: 0.4557 - val_loss: 5.5567 - val_accuracy: 0.4336
# Epoch 9/30
# 24/24 [==============================] - ETA: 0s - loss: 6.2702 - accuracy: 0.4479
# Epoch 9: val_accuracy improved from 0.43750 to 0.47656, saving model to best_model.h5
# 24/24 [==============================] - 49s 2s/step - loss: 6.2702 - accuracy: 0.4479 - val_loss: 6.7981 - val_accuracy: 0.4766
# Epoch 10/30
# 24/24 [==============================] - ETA: 0s - loss: 6.0759 - accuracy: 0.4518
# Epoch 10: val_accuracy improved from 0.47656 to 0.49609, saving model to best_model.h5
# 24/24 [==============================] - 57s 2s/step - loss: 6.0759 - accuracy: 0.4518 - val_loss: 6.9717 - val_accuracy: 0.4961
# Epoch 11/30
# 24/24 [==============================] - ETA: 0s - loss: 5.8907 - accuracy: 0.4922
# Epoch 11: val_accuracy did not improve from 0.49609
# 24/24 [==============================] - 50s 2s/step - loss: 5.8907 - accuracy: 0.4922 - val_loss: 5.3965 - val_accuracy: 0.4844
# Epoch 12/30
# 24/24 [==============================] - ETA: 0s - loss: 5.9495 - accuracy: 0.4701
# Epoch 12: val_accuracy did not improve from 0.49609
# 24/24 [==============================] - 50s 2s/step - loss: 5.9495 - accuracy: 0.4701 - val_loss: 6.0487 - val_accuracy: 0.4531
# Epoch 13/30
# 24/24 [==============================] - ETA: 0s - loss: 6.5520 - accuracy: 0.4683
# Epoch 13: val_accuracy did not improve from 0.49609
# 24/24 [==============================] - 50s 2s/step - loss: 6.5520 - accuracy: 0.4683 - val_loss: 6.2376 - val_accuracy: 0.4609
# Epoch 14/30
# 24/24 [==============================] - ETA: 0s - loss: 8.1743 - accuracy: 0.4310
# Epoch 14: val_accuracy did not improve from 0.49609
# 24/24 [==============================] - 48s 2s/step - loss: 8.1743 - accuracy: 0.4310 - val_loss: 10.4897 - val_accuracy: 0.3828
# Epoch 15/30
# 24/24 [==============================] - ETA: 0s - loss: 8.0887 - accuracy: 0.4570
# Epoch 15: val_accuracy did not improve from 0.49609
# 24/24 [==============================] - 42s 2s/step - loss: 8.0887 - accuracy: 0.4570 - val_loss: 8.8955 - val_accuracy: 0.4102
# Epoch 15: early stopping

# %%
# Loading the best fit model 
from keras.models import load_model
model = load_model("best_model.h5")

# %%
h =  hist.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'] , c = "red")
plt.title("acc vs v-acc")
plt.show()

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'] , c = "red")
plt.title("loss vs v-loss")
plt.show()

# %%
# just to map o/p values 
op = dict(zip( train_data.class_indices.values(), train_data.class_indices.keys()))

# %%
# path for the image to see if it predics correct class

path = "./dataset/test/angry/PrivateTest_1054527.jpg"
img = load_img(path, target_size=(224,224) )

i = img_to_array(img)/255
input_arr = np.array([i])
input_arr.shape

pred = np.argmax(model.predict(input_arr))

print(f" the image is of {op[pred]}")

# to display the image  
plt.imshow(input_arr[0])
plt.title("input image")
plt.show()
# Out:
# 1/1 [==============================] - 3s 3s/step
#  the image is of sad
